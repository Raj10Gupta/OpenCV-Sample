# %% [markdown]
# # If you are detecting Green Colour
# lower_green = np.array([65,60,60])
# upper_green = np.array([80,255,255])
#
# # If you are detecting for RED COLOR
# lower_range = np.array([0,100,100])
# upper_range = np.array([5,255,255])

# %%
import cv2
import numpy as np

# %%
img = cv2.imread(r'C:\Users\rj100\OneDrive\Pictures\3.jpg')

# %%
image = cv2.imread(r'C:\Users\rj100\OneDrive\Pictures\3.jpg')

# %%
hsv = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)

# %%
lower_blue = np.array([110,50,50])
upper_blue = np.array([130,255,255])
mask = cv2.inRange(hsv, lower_blue, upper_blu)

# %%
cv2.imshow('image_window_name', image)
cv2.imshow('mask_window_name', mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

plt.imshow(mask)

# %%
plt.imshow(img)
